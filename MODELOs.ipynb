# %%
from PIL import Image
import base64
from io import BytesIO
from transformers import BlipProcessor, BlipForConditionalGeneration

processor = BlipProcessor.from_pretrained("michelecafagna26/blip-base-captioning-ft-hl-narratives")
model = BlipForConditionalGeneration.from_pretrained("michelecafagna26/blip-base-captioning-ft-hl-narratives")

def decode_base64_image(base64_str):
    image_bytes = base64.b64decode(base64_str)
    return Image.open(BytesIO(image_bytes))

image = decode_base64_image(variablexenbase)
text = "Describe this image in detail:"

inputs = processor(images=image, text=text, return_tensors="pt", truncation=True)
outputs = model.generate(
    **inputs,
    max_length=70,
    min_length=40,
    num_beams=5,
    repetition_penalty=1.2
)
caption = processor.decode(outputs[0], skip_special_tokens=True)

print(caption)

# %%
from PIL import Image
import base64
from io import BytesIO
from transformers import BlipProcessor, BlipForConditionalGeneration


processor = BlipProcessor.from_pretrained("michelecafagna26/blip-base-captioning-ft-hl-rationales")
model = BlipForConditionalGeneration.from_pretrained("michelecafagna26/blip-base-captioning-ft-hl-rationales")


def decode_base64_image(base64_str):
    image_bytes = base64.b64decode(base64_str)
    return Image.open(BytesIO(image_bytes))

image = decode_base64_image(variablexenbase)
text = "A picture of"

inputs = processor(images=image, text=text, return_tensors="pt",truncation=True)
outputs = model.generate(
    **inputs,
    max_length=70,
    min_length=40,
    num_beams=5,
    repetition_penalty=1.2
)
caption = processor.decode(outputs[0], skip_special_tokens=True)

print(caption)

# %%
from PIL import Image
import base64
from io import BytesIO
from transformers import BlipProcessor, BlipForConditionalGeneration


processor = BlipProcessor.from_pretrained("michelecafagna26/blip-base-captioning-ft-hl-scenes")
model =  BlipForConditionalGeneration.from_pretrained("michelecafagna26/blip-base-captioning-ft-hl-scenes")


def decode_base64_image(base64_str):
    image_bytes = base64.b64decode(base64_str)
    return Image.open(BytesIO(image_bytes))

image = decode_base64_image(variablexenbase)
text = "A picture of"

inputs = processor(images=image, text=text, return_tensors="pt")
outputs = model.generate(
    **inputs,
    max_length=70,
    min_length=40,
    num_beams=5,
    repetition_penalty=1.2
)
caption = processor.decode(outputs[0], skip_special_tokens=True)

print(caption)

# %%
from PIL import Image
import base64
from io import BytesIO
from transformers import BlipProcessor, BlipForConditionalGeneration


processor = BlipProcessor.from_pretrained("nnpy/blip-image-captioning")
model = BlipForConditionalGeneration.from_pretrained("nnpy/blip-image-captioning")




def decode_base64_image(base64_str):
    image_bytes = base64.b64decode(base64_str)
    return Image.open(BytesIO(image_bytes))

image = decode_base64_image(variablexenbase)
text = "A picture of"

inputs = processor(images=image, text=text, return_tensors="pt")
outputs = model.generate(
    **inputs,
    max_length=70,
    min_length=40,
    num_beams=5,
    repetition_penalty=1.2
)
caption = processor.decode(outputs[0], skip_special_tokens=True)

print(caption)

# %%
from PIL import Image
import base64
from io import BytesIO
from transformers import BlipProcessor, BlipForConditionalGeneration


processor =  BlipProcessor.from_pretrained("muhammedaydiiinnn/blip-flickr8k-caption")
model = BlipForConditionalGeneration.from_pretrained("muhammedaydiiinnn/blip-flickr8k-caption")


def decode_base64_image(base64_str):
    image_bytes = base64.b64decode(base64_str)
    return Image.open(BytesIO(image_bytes))

image = decode_base64_image(variablexenbase)
text = "A picture of"

inputs = processor(images=image, text=text, return_tensors="pt")
outputs = model.generate(
    **inputs,
    max_length=70,
    min_length=40,
    num_beams=5,
    repetition_penalty=1.2
)
caption = processor.decode(outputs[0], skip_special_tokens=True)

print(caption)

# %%
from PIL import Image
import base64
from io import BytesIO
from transformers import BlipProcessor, BlipForConditionalGeneration

processor = BlipProcessor.from_pretrained("omarsabri8756/blip-merged-lora-flickr-30k")
model = BlipForConditionalGeneration.from_pretrained("omarsabri8756/blip-merged-lora-flickr-30k")

def decode_base64_image(base64_str):
    image_bytes = base64.b64decode(base64_str)
    return Image.open(BytesIO(image_bytes))

image = decode_base64_image(variablexenbase)
text = "A picture of"

inputs = processor(images=image, text=text, return_tensors="pt",truncation=True)
outputs = model.generate(
    **inputs,
    max_length=70,
    min_length=40,
    num_beams=5,
    repetition_penalty=1.2
)
caption = processor.decode(outputs[0], skip_special_tokens=True)

print(caption)

# %%
from transformers import AutoTokenizer, AutoImageProcessor, VisionEncoderDecoderModel
import base64, time
from io import BytesIO
from PIL import Image


model = VisionEncoderDecoderModel.from_pretrained("cnmoro/tiny-image-captioning")
tokenizer = AutoTokenizer.from_pretrained("cnmoro/tiny-image-captioning")
image_processor = AutoImageProcessor.from_pretrained("cnmoro/tiny-image-captioning")

def decode_base64_image(base64_str):
    image_bytes = base64.b64decode(base64_str)
    return Image.open(BytesIO(image_bytes))

image = decode_base64_image(variablexenbase)
pixel_values = image_processor(image, return_tensors="pt").pixel_values

start = time.time()

generated_ids = model.generate(
    pixel_values,
    max_length=50,
    min_length=15,
    temperature=0.7,
    top_p=0.8,
    top_k=50,
    num_beams=3
)
generated_text = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]

end = time.time()

print(generated_text)
print(f"Time taken: {end - start} seconds")

# %%
from transformers import AutoTokenizer, AutoImageProcessor, VisionEncoderDecoderModel
import base64, time
from io import BytesIO
from PIL import Image


model = VisionEncoderDecoderModel.from_pretrained("cnmoro/mini-image-captioning")
tokenizer = AutoTokenizer.from_pretrained("cnmoro/mini-image-captioning")
image_processor = AutoImageProcessor.from_pretrained("cnmoro/mini-image-captioning")

def decode_base64_image(base64_str):
    image_bytes = base64.b64decode(base64_str)
    return Image.open(BytesIO(image_bytes))

image = decode_base64_image(variablexenbase)
pixel_values = image_processor(image, return_tensors="pt").pixel_values

start = time.time()

generated_ids = model.generate(
    pixel_values,
    max_length=50,
    min_length=25,
    temperature=0.7,
    top_p=0.8,
    top_k=50,
    num_beams=3
)
generated_text = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]

end = time.time()

print(generated_text)
print(f"Time taken: {end - start} seconds")

# %%
from transformers import AutoProcessor, VisionEncoderDecoderModel
import base64
from io import BytesIO
from PIL import Image


processor = AutoProcessor.from_pretrained("deepakachu/rsicd_image_captioning")
model = VisionEncoderDecoderModel.from_pretrained("deepakachu/rsicd_image_captioning")

def decode_base64_image(base64_str):
    image_bytes = base64.b64decode(base64_str)
    return Image.open(BytesIO(image_bytes))


image = decode_base64_image(variablexenbase)

pixel_values = processor(images=image, return_tensors="pt").pixel_values

generated_ids = model.generate(pixel_values, max_length=50, num_beams=3)
generated_caption = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]

print(generated_caption)


#error
##You are using a model of type git to instantiate a model of type vision-encoder-decoder. This is not supported for all configurations of models and can yield errors.

# %%
from transformers import AutoTokenizer, AutoFeatureExtractor, VisionEncoderDecoderModel
import base64
from io import BytesIO
from PIL import Image


model = VisionEncoderDecoderModel.from_pretrained("deepakachu/rsicd_image_captioning")
tokenizer = AutoTokenizer.from_pretrained("deepakachu/rsicd_image_captioning")


feature_extractor = AutoFeatureExtractor.from_pretrained("nlpconnect/vit-gpt2-image-captioning")

def decode_base64_image(base64_str):
    image_bytes = base64.b64decode(base64_str)
    return Image.open(BytesIO(image_bytes))

image = decode_base64_image(variablexenbase)
pixel_values = feature_extractor(images=image, return_tensors="pt").pixel_values

generated_ids = model.generate(pixel_values, max_length=50, num_beams=3)
caption = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)[0]

print(caption)
